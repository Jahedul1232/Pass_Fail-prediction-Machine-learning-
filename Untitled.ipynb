# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('student_database.csv')
df.head(5)
# Out:
#            SL.NO         USN           STUDENT NAME  TEST1  TEST2  QUIZ1  \
# 0  MAXIMUM MARKS         NaN                    NaN   50.0   50.0   10.0
# 1              1  1RV17MCA01           CHAITHRA M N   11.0    9.0    3.0
# 2              2  1RV17MCA02     CHANDRAMOHAN KUMAR   28.0   26.0    9.0
# 3              3  1RV17MCA03            DARSHAN G N   18.0   12.0    9.0
# 4              4  1RV17MCA04  DARSHAN SHANIYAR NAIK   25.0   14.0    7.0
#
#    QUIZ2  FinalTest  Assignment  CIE  SEE     Result
# 0   10.0         50        30.0  100  100  Pass/Fail
# 1    7.0         10        12.0   32    0          F
# 2    7.0         27        17.0   60   50          P
# 3    5.0         15        12.0   41   63          P
# 4    6.0         19        20.0   52   54          P

# %%
df.shape
# Out:
# (119, 12)

# %%
sns.countplot(x = 'Result',data = df)

# %%
df.isnull()
# Out:
#      SL.NO    USN  STUDENT NAME  TEST1  TEST2  QUIZ1  QUIZ2  FinalTest  \
# 0    False   True          True  False  False  False  False      False
# 1    False  False         False  False  False  False  False      False
# 2    False  False         False  False  False  False  False      False
# 3    False  False         False  False  False  False  False      False
# 4    False  False         False  False  False  False  False      False
# ..     ...    ...           ...    ...    ...    ...    ...        ...
# 114  False  False         False  False  False  False  False      False
# 115  False  False         False  False  False  False  False      False
# 116  False  False         False  False  False  False  False      False
# 117  False  False         False  False  False  False  False      False
# 118  False  False         False  False  False  False  False      False
#
#      Assignment    CIE    SEE  Result
# 0         False  False  False   False
# 1         False  False  False   False
# 2         False  False  False   False
# 3         False  False  False   False
# 4         False  False  False   False
# ..          ...    ...    ...     ...
# 114       False  False  False   False
# 115       False  False  False   False
# 116       False  False  False   False
# 117       False  False  False   False
# 118       False  False  False   False
#
# [119 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SL.NO         119 non-null    object
#  1   USN           118 non-null    object
#  2   STUDENT NAME  118 non-null    object
#  3   TEST1         111 non-null    float64
#  4   TEST2         114 non-null    float64
#  5   QUIZ1         111 non-null    float64
#  6   QUIZ2         114 non-null    float64
#  7   FinalTest     119 non-null    int64
#  8   Assignment    115 non-null    float64
#  9   CIE           119 non-null    int64
#  10  SEE           119 non-null    int64
#  11  Result        114 non-null    object
# dtypes: float64(5), int64(3), object(4)
# memory usage: 11.3+ KB

# %%
df.isnull().sum()
# Out:
# SL.NO           0
# USN             1
# STUDENT NAME    1
# TEST1           8
# TEST2           5
# QUIZ1           8
# QUIZ2           5
# FinalTest       0
# Assignment      4
# CIE             0
# SEE             0
# Result          5
# dtype: int64

# %%
sns.heatmap(df.isnull(), yticklabels=False)

# %%
df
# Out:
#              SL.NO         USN               STUDENT NAME  TEST1  TEST2  \
# 0    MAXIMUM MARKS         NaN                        NaN   50.0   50.0
# 1                1  1RV17MCA01               CHAITHRA M N   11.0    9.0
# 2                2  1RV17MCA02         CHANDRAMOHAN KUMAR   28.0   26.0
# 3                3  1RV17MCA03                DARSHAN G N   18.0   12.0
# 4                4  1RV17MCA04      DARSHAN SHANIYAR NAIK   25.0   14.0
# ..             ...         ...                        ...    ...    ...
# 114            114  1RZ17MCA55             VISHAL V JOSHI   31.0   34.0
# 115            115  1RZ17MCA56           VRUSHAB PREMNATH   19.0   15.0
# 116            116  1RZ17MCA57  YASHODA SHANMUKH HUBBALLI   27.0   30.0
# 117            117  1RZ17MCA58                  YASHWANTH   28.0   33.0
# 118            118  1RZ17MCA59           YOGESH KURIYAVAR   38.0   33.0
#
#      QUIZ1  QUIZ2  FinalTest  Assignment  CIE  SEE     Result
# 0     10.0   10.0         50        30.0  100  100  Pass/Fail
# 1      3.0    7.0         10        12.0   32    0          F
# 2      9.0    7.0         27        17.0   60   50          P
# 3      9.0    5.0         15        12.0   41   63          P
# 4      7.0    6.0         19        20.0   52   54          P
# ..     ...    ...        ...         ...  ...  ...        ...
# 114    8.0    8.0         32        27.0   75   72          P
# 115    5.0    3.0         17        20.0   45   66          P
# 116    8.0    6.0         28        18.0   60   58          P
# 117    8.0    8.0         30        26.0   72   68          P
# 118    7.0    5.0         35        30.0   77   78          P
#
# [119 rows x 12 columns]

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#     SL.NO         USN               STUDENT NAME  TEST1  TEST2  QUIZ1  QUIZ2  \
# 1       1  1RV17MCA01               CHAITHRA M N   11.0    9.0    3.0    7.0
# 2       2  1RV17MCA02         CHANDRAMOHAN KUMAR   28.0   26.0    9.0    7.0
# 3       3  1RV17MCA03                DARSHAN G N   18.0   12.0    9.0    5.0
# 4       4  1RV17MCA04      DARSHAN SHANIYAR NAIK   25.0   14.0    7.0    6.0
# 5       5  1RV17MCA05          DEEP RANJAN KUMAR   21.0   21.0    9.0    5.0
# ..    ...         ...                        ...    ...    ...    ...    ...
# 114   114  1RZ17MCA55             VISHAL V JOSHI   31.0   34.0    8.0    8.0
# 115   115  1RZ17MCA56           VRUSHAB PREMNATH   19.0   15.0    5.0    3.0
# 116   116  1RZ17MCA57  YASHODA SHANMUKH HUBBALLI   27.0   30.0    8.0    6.0
# 117   117  1RZ17MCA58                  YASHWANTH   28.0   33.0    8.0    8.0
# 118   118  1RZ17MCA59           YOGESH KURIYAVAR   38.0   33.0    7.0    5.0
#
#      FinalTest  Assignment  CIE  SEE Result
# 1           10        12.0   32    0      F
# 2           27        17.0   60   50      P
# 3           15        12.0   41   63      P
# 4           19        20.0   52   54      P
# 5           21        20.0   55   62      P
# ..         ...         ...  ...  ...    ...
# 114         32        27.0   75   72      P
# 115         17        20.0   45   66      P
# 116         28        18.0   60   58      P
# 117         30        26.0   72   68      P
# 118         35        30.0   77   78      P
#
# [109 rows x 12 columns]

# %%
sns.heatmap(df.isnull(),yticklabels=False)

# %%
df.isnull().sum()
# Out:
# SL.NO           0
# USN             0
# STUDENT NAME    0
# TEST1           0
# TEST2           0
# QUIZ1           0
# QUIZ2           0
# FinalTest       0
# Assignment      0
# CIE             0
# SEE             0
# Result          0
# dtype: int64

# %%
df.head()
# Out:
#   SL.NO         USN           STUDENT NAME  TEST1  TEST2  QUIZ1  QUIZ2  \
# 1     1  1RV17MCA01           CHAITHRA M N   11.0    9.0    3.0    7.0
# 2     2  1RV17MCA02     CHANDRAMOHAN KUMAR   28.0   26.0    9.0    7.0
# 3     3  1RV17MCA03            DARSHAN G N   18.0   12.0    9.0    5.0
# 4     4  1RV17MCA04  DARSHAN SHANIYAR NAIK   25.0   14.0    7.0    6.0
# 5     5  1RV17MCA05      DEEP RANJAN KUMAR   21.0   21.0    9.0    5.0
#
#    FinalTest  Assignment  CIE  SEE Result
# 1         10        12.0   32    0      F
# 2         27        17.0   60   50      P
# 3         15        12.0   41   63      P
# 4         19        20.0   52   54      P
# 5         21        20.0   55   62      P

# %%
#df =  pd.get_dummies(data =df,columns = ['Result'],drop_first =True )

# %%
df
# Out:
#     SL.NO         USN               STUDENT NAME  TEST1  TEST2  QUIZ1  QUIZ2  \
# 1       1  1RV17MCA01               CHAITHRA M N   11.0    9.0    3.0    7.0
# 2       2  1RV17MCA02         CHANDRAMOHAN KUMAR   28.0   26.0    9.0    7.0
# 3       3  1RV17MCA03                DARSHAN G N   18.0   12.0    9.0    5.0
# 4       4  1RV17MCA04      DARSHAN SHANIYAR NAIK   25.0   14.0    7.0    6.0
# 5       5  1RV17MCA05          DEEP RANJAN KUMAR   21.0   21.0    9.0    5.0
# ..    ...         ...                        ...    ...    ...    ...    ...
# 114   114  1RZ17MCA55             VISHAL V JOSHI   31.0   34.0    8.0    8.0
# 115   115  1RZ17MCA56           VRUSHAB PREMNATH   19.0   15.0    5.0    3.0
# 116   116  1RZ17MCA57  YASHODA SHANMUKH HUBBALLI   27.0   30.0    8.0    6.0
# 117   117  1RZ17MCA58                  YASHWANTH   28.0   33.0    8.0    8.0
# 118   118  1RZ17MCA59           YOGESH KURIYAVAR   38.0   33.0    7.0    5.0
#
#      FinalTest  Assignment  CIE  SEE Result
# 1           10        12.0   32    0      F
# 2           27        17.0   60   50      P
# 3           15        12.0   41   63      P
# 4           19        20.0   52   54      P
# 5           21        20.0   55   62      P
# ..         ...         ...  ...  ...    ...
# 114         32        27.0   75   72      P
# 115         17        20.0   45   66      P
# 116         28        18.0   60   58      P
# 117         30        26.0   72   68      P
# 118         35        30.0   77   78      P
#
# [109 rows x 12 columns]

# %%
X = df.iloc[: , 3:11]
y = df.iloc[:,11]

# %%
X
# Out:
#      TEST1  TEST2  QUIZ1  QUIZ2  FinalTest  Assignment  CIE  SEE
# 1     11.0    9.0    3.0    7.0         10        12.0   32    0
# 2     28.0   26.0    9.0    7.0         27        17.0   60   50
# 3     18.0   12.0    9.0    5.0         15        12.0   41   63
# 4     25.0   14.0    7.0    6.0         19        20.0   52   54
# 5     21.0   21.0    9.0    5.0         21        20.0   55   62
# ..     ...    ...    ...    ...        ...         ...  ...  ...
# 114   31.0   34.0    8.0    8.0         32        27.0   75   72
# 115   19.0   15.0    5.0    3.0         17        20.0   45   66
# 116   27.0   30.0    8.0    6.0         28        18.0   60   58
# 117   28.0   33.0    8.0    8.0         30        26.0   72   68
# 118   38.0   33.0    7.0    5.0         35        30.0   77   78
#
# [109 rows x 8 columns]

# %%
y
# Out:
# 1      F
# 2      P
# 3      P
# 4      P
# 5      P
#       ..
# 114    P
# 115    P
# 116    P
# 117    P
# 118    P
# Name: Result, Length: 109, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test , y_train , y_test = train_test_split(X,y , test_size= 0.3 , random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
regressor = LogisticRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_test.shape
# Out:
# (33, 8)

# %%
pred = regressor.predict(X_test)

# %%
pred
# Out:
# array(['P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'F', 'P', 'F', 'P',
#        'P', 'P', 'P', 'P', 'F', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'F',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P'], dtype=object)

# %%
y_test
# Out:
# 91     P
# 11     P
# 82     P
# 3      P
# 25     P
# 110    P
# 118    P
# 8      P
# 17     P
# 94     F
# 75     P
# 23     F
# 50     P
# 66     P
# 83     P
# 57     P
# 14     P
# 80     F
# 92     P
# 60     P
# 114    P
# 9      P
# 27     P
# 102    P
# 34     P
# 4      P
# 73     P
# 53     P
# 31     P
# 7      P
# 85     P
# 98     P
# 99     P
# Name: Result, dtype: object

# %%
from sklearn.metrics import classification_report
print(classification_report(pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            F       1.00      0.75      0.86         4
#            P       0.97      1.00      0.98        29
#
#     accuracy                           0.97        33
#    macro avg       0.98      0.88      0.92        33
# weighted avg       0.97      0.97      0.97        33

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(pred, y_test)
# Out:
# array([[ 3,  1],
#        [ 0, 29]], dtype=int64)
